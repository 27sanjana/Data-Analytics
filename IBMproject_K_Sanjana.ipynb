# %%
import numpy as np
import pandas as pd

# %%
df= pd.read_csv('/content/drive/MyDrive/Sample_ Superstore.csv')
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156  11-08-2016  11-11-2016    Second Class    CG-12520
# 1       2  CA-2016-152156  11-08-2016  11-11-2016    Second Class    CG-12520
# 2       3  CA-2016-138688  06-12-2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10-11-2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10-11-2015  10/18/2015  Standard Class    SO-20335
#
#      Segment        Country             City       State Region  \
# 0   Consumer  United States        Henderson    Kentucky  South
# 1   Consumer  United States        Henderson    Kentucky  South
# 2  Corporate  United States      Los Angeles  California   West
# 3   Consumer  United States  Fort Lauderdale     Florida  South
# 4   Consumer  United States  Fort Lauderdale     Florida  South
#
#         Product ID         Category Sub-Category  \
# 0  FUR-BO-10001798        Furniture    Bookcases
# ...

# %%
df.shape
# Out:
# (9994, 19)

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Segment', 'Country', 'City', 'State', 'Region',
#        'Product ID', 'Category', 'Sub-Category', 'Product Name', 'Sales',
#        'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
data= df.drop(columns=['Row ID','Order Date','Ship Date','Customer ID','Product ID'], axis=1)
data.head()
# Out:
#          Order ID       Ship Mode    Segment        Country             City  \
# 0  CA-2016-152156    Second Class   Consumer  United States        Henderson
# 1  CA-2016-152156    Second Class   Consumer  United States        Henderson
# 2  CA-2016-138688    Second Class  Corporate  United States      Los Angeles
# 3  US-2015-108966  Standard Class   Consumer  United States  Fort Lauderdale
# 4  US-2015-108966  Standard Class   Consumer  United States  Fort Lauderdale
#
#         State Region         Category Sub-Category  \
# 0    Kentucky  South        Furniture    Bookcases
# 1    Kentucky  South        Furniture       Chairs
# 2  California   West  Office Supplies       Labels
# 3     Florida  South        Furniture       Tables
# 4     Florida  South  Office Supplies      Storage
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# ...

# %%
df.shape
# Out:
# (9994, 19)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Row ID        9994 non-null   int64
#  1   Order ID      9994 non-null   object
#  2   Order Date    9994 non-null   object
#  3   Ship Date     9994 non-null   object
#  4   Ship Mode     9994 non-null   object
#  5   Customer ID   9994 non-null   object
#  6   Segment       9994 non-null   object
#  7   Country       9994 non-null   object
#  8   City          9994 non-null   object
#  9   State         9994 non-null   object
#  10  Region        9994 non-null   object
#  11  Product ID    9994 non-null   object
#  12  Category      9994 non-null   object
#  13  Sub-Category  9994 non-null   object
#  14  Product Name  9994 non-null   object
#  15  Sales         9994 non-null   float64
#  16  Quantity      9994 non-null   int64
#  17  Discount      9994 non-null   float64
# ...

# %%
df.describe()
# Out:
#             Row ID         Sales     Quantity     Discount       Profit
# count  9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   4997.500000    229.858001     3.789574     0.156203    28.656896
# std    2885.163629    623.245101     2.225110     0.206452   234.260108
# min       1.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    2499.250000     17.280000     2.000000     0.000000     1.728750
# 50%    4997.500000     54.490000     3.000000     0.200000     8.666500
# 75%    7495.750000    209.940000     5.000000     0.200000    29.364000
# max    9994.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
data= df.drop(columns=['Row ID','Order ID','Order Date', 'Ship Date','Customer ID','Product ID'], axis=1)
data.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#   Region         Category Sub-Category  \
# 0  South        Furniture    Bookcases
# 1  South        Furniture       Chairs
# 2   West  Office Supplies       Labels
# 3  South        Furniture       Tables
# 4  South  Office Supplies      Storage
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# ...

# %%
data.shape
# Out:
# (9994, 13)

# %%
data.corr()
# Out:
# <ipython-input-59-c44ded798807>:1: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#              Sales  Quantity  Discount    Profit
# Sales     1.000000  0.200795 -0.028190  0.479064
# Quantity  0.200795  1.000000  0.008623  0.066253
# Discount -0.028190  0.008623  1.000000 -0.219487
# Profit    0.479064  0.066253 -0.219487  1.000000

# %%
import seaborn as sns
ax= sns.heatmap(data.corr(),annot=True)
ax.set(xlabel="",ylabel="")
# Out:
# <ipython-input-60-b1615ffc0347>:2: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# [Text(0.5, 23.52222222222222, ''), Text(50.722222222222214, 0.5, '')]

# %% [markdown]
# # Top 10 Most profit cities

# %%
data['City'].unique()
# Out:
# array(['Henderson', 'Los Angeles', 'Fort Lauderdale', 'Concord',
#        'Seattle', 'Fort Worth', 'Madison', 'West Jordan', 'San Francisco',
#        'Fremont', 'Philadelphia', 'Orem', 'Houston', 'Richardson',
#        'Naperville', 'Melbourne', 'Eagan', 'Westland', 'Dover',
#        'New Albany', 'New York City', 'Troy', 'Chicago', 'Gilbert',
#        'Springfield', 'Jackson', 'Memphis', 'Decatur', 'Durham',
#        'Columbia', 'Rochester', 'Minneapolis', 'Portland', 'Saint Paul',
#        'Aurora', 'Charlotte', 'Orland Park', 'Urbandale', 'Columbus',
#        'Bristol', 'Wilmington', 'Bloomington', 'Phoenix', 'Roseville',
#        'Independence', 'Pasadena', 'Newark', 'Franklin', 'Scottsdale',
#        'San Jose', 'Edmond', 'Carlsbad', 'San Antonio', 'Monroe',
#        'Fairfield', 'Grand Prairie', 'Redlands', 'Hamilton', 'Westfield',
#        'Akron', 'Denver', 'Dallas', 'Whittier', 'Saginaw', 'Medina',
#        'Dublin', 'Detroit', 'Tampa', 'Santa Clara', 'Lakeville',
# ...

# %%
city_profit= pd.DataFrame(data.groupby("City")["Profit"].sum())
city_profit.reset_index(inplace=True)
city_profit= city_profit.sort_values(by="Profit",ascending=False)
city_profit.head(10)
# Out:
#               City      Profit
# 329  New York City  62036.9837
# 266    Los Angeles  30440.7579
# 452        Seattle  29156.0967
# 438  San Francisco  17507.3854
# 123        Detroit  13181.7908
# 233      Lafayette  10018.3876
# 215        Jackson   7581.6828
# 21         Atlanta   6993.6629
# 300    Minneapolis   6824.5846
# 437      San Diego   6377.1960

# %%
import plotly.express as px
figure=px.treemap(city_profit, path=['City','Profit'], values='Profit',color='Profit')
figure.update_layout(width=1000, height=500)
figure.update_layout(title="Top 10 Most Profitable Cities",width=1000,height=500)
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Top 10 most profit states

# %%
data["State"].unique()
# Out:
# array(['Kentucky', 'California', 'Florida', 'North Carolina',
#        'Washington', 'Texas', 'Wisconsin', 'Utah', 'Nebraska',
#        'Pennsylvania', 'Illinois', 'Minnesota', 'Michigan', 'Delaware',
#        'Indiana', 'New York', 'Arizona', 'Virginia', 'Tennessee',
#        'Alabama', 'South Carolina', 'Oregon', 'Colorado', 'Iowa', 'Ohio',
#        'Missouri', 'Oklahoma', 'New Mexico', 'Louisiana', 'Connecticut',
#        'New Jersey', 'Massachusetts', 'Georgia', 'Nevada', 'Rhode Island',
#        'Mississippi', 'Arkansas', 'Montana', 'New Hampshire', 'Maryland',
#        'District of Columbia', 'Kansas', 'Vermont', 'Maine',
#        'South Dakota', 'Idaho', 'North Dakota', 'Wyoming',
#        'West Virginia'], dtype=object)

# %%
state_profit= pd.DataFrame(data.groupby("State")["Profit"].sum())
state_profit.reset_index(inplace=True)
state_profit= state_profit.sort_values(by="Profit", ascending=False)
state_profit.head(10)
# Out:
#          State      Profit
# 3   California  76381.3871
# 30    New York  74038.5486
# 45  Washington  33402.6517
# 20    Michigan  24463.1876
# 44    Virginia  18597.9504
# 12     Indiana  18382.9363
# 9      Georgia  16250.0433
# 15    Kentucky  11199.6966
# 21   Minnesota  10823.1874
# 6     Delaware   9977.3748

# %%
figure= px.treemap(state_profit,path=["State","Profit"],values="Profit",color="Profit")
figure.update_layout(width=1000, height=500)
figure.update_layout(title="Top 10 Most Profitable States",width=1000,height=500)
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Most profiable Sub_category

# %%
data["Sub-Category"].unique()
# Out:
# array(['Bookcases', 'Chairs', 'Labels', 'Tables', 'Storage',
#        'Furnishings', 'Art', 'Phones', 'Binders', 'Appliances', 'Paper',
#        'Accessories', 'Envelopes', 'Fasteners', 'Supplies', 'Machines',
#        'Copiers'], dtype=object)

# %%
sub_category = pd.DataFrame(data.groupby("Sub-Category")["Profit"].sum())
sub_category.reset_index(inplace=True)
sub_category_profit= sub_category.sort_values(by="Profit",ascending=False)
sub_category_profit.head(10)
# Out:
#    Sub-Category      Profit
# 6       Copiers  55617.8249
# 13       Phones  44515.7306
# 0   Accessories  41936.6357
# 12        Paper  34053.5693
# 3       Binders  30221.7633
# 5        Chairs  26590.1663
# 14      Storage  21278.8264
# 1    Appliances  18138.0054
# 9   Furnishings  13059.1436
# 7     Envelopes   6964.1767

# %%
import matplotlib.pyplot as plt
plt.bar(sub_category_profit["Sub-Category"],sub_category_profit["Profit"])
plt.xlabel("Sub-Categories")
plt.xticks(sub_category_profit["Sub-Category"],rotation="vertical")
plt.ylabel("Profit")
plt.title("Most Profitable Sub-Category")
plt.show()

# %% [markdown]
# # Most selling Category

# %%
data["Category"].value_counts()
# Out:
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: Category, dtype: int64

# %%
category_sale= data.groupby("Category").sum()
category_sale.reset_index(inplace=True)
category_sale.head(10)
# Out:
# <ipython-input-71-a25a10785f2c>:1: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#           Category        Sales  Quantity  Discount       Profit
# 0        Furniture  741999.7953      8028    368.89   18451.2728
# 1  Office Supplies  719047.0320     22906    947.80  122490.8008
# 2       Technology  836154.0330      6939    244.40  145454.9481

# %%
plt.bar(category_sale["Category"], category_sale["Sales"])
plt.xticks(category_sale.index)
plt.xlabel("Category")
plt.ylabel("Sales")
plt.title("Most Selling Category")
plt.show()

# %% [markdown]
# # Most popular Sub-Category

# %%
sub_category_popular= pd.DataFrame(data.groupby("Sub-Category")["Quantity"].sum())
sub_category_popular.reset_index(inplace=True)
sub_category_popular= sub_category_popular.sort_values(by="Quantity",ascending=False)

# %%
plt.bar(sub_category_popular["Sub-Category"],sub_category_popular["Quantity"],color="green")
plt.xticks(sub_category_popular["Sub-Category"],rotation="vertical")
plt.title("Most Popoular Sub-Category")
plt.xlabel("Sub Category")
plt.ylabel("Quantity")
plt.show()

# %% [markdown]
# # Most Profitable Customer Segment

# %%
cstmr_segment= data.groupby("Segment").sum()
cstmr_segment.reset_index(inplace=True)
cstmr_segment
# Out:
# <ipython-input-75-a4d48534601a>:1: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#        Segment         Sales  Quantity  Discount       Profit
# 0     Consumer  1.161401e+06     19521    820.91  134119.2092
# 1    Corporate  7.061464e+05     11608    477.85   91979.1340
# 2  Home Office  4.296531e+05      6744    262.33   60298.6785

# %%
plt.bar(cstmr_segment["Segment"],cstmr_segment["Profit"],color="red")
plt.xticks(cstmr_segment["Segment"],rotation="vertical")
plt.title("Most Profitable Customer Segment")
plt.xlabel("Segment")
plt.ylabel("Profit")
plt.show()

# %% [markdown]
# # Most Profitable Region

# %%
data["Region"].value_counts()
# Out:
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: Region, dtype: int64

# %%
region_profit= pd.DataFrame(data.groupby("Region")["Profit"].sum())
region_profit.reset_index(inplace=True)
region_profit
# Out:
#     Region       Profit
# 0  Central   39706.3625
# 1     East   91522.7800
# 2    South   46749.4303
# 3     West  108418.4489

# %%
plt.bar(region_profit["Region"],region_profit["Profit"],color="pink")
plt.xticks(region_profit["Region"],rotation="vertical")
plt.title("Most Profitable Region")
plt.xlabel("Region")
plt.ylabel("Profit")
plt.show()

# %% [markdown]
# #Which City has Highest Sales Volume

# %%
city_volume= pd.DataFrame(data.groupby("City")["Sales"].sum())
city_volume= city_volume.sort_values(by="Sales",ascending=False)
city_volume.head()
# Out:
#                     Sales
# City
# New York City  256368.161
# Los Angeles    175851.341
# Seattle        119540.742
# San Francisco  112669.092
# Philadelphia   109077.013

# %%
plt.bar(city_volume.index[0:20], city_volume['Sales'][0:20], color="yellow")
plt.xticks(city_volume.index[0:20],rotation='vertical')
plt.xlabel("City")
plt.ylabel("Sales")
plt.title("Cities with Highest Sales Volume ")
plt.show()

# %% [markdown]
# # Building a ML model to predict profit

# %%
data.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#   Region         Category Sub-Category  \
# 0  South        Furniture    Bookcases
# 1  South        Furniture       Chairs
# 2   West  Office Supplies       Labels
# 3  South        Furniture       Tables
# 4  South  Office Supplies      Storage
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# ...

# %%
datafinal = data.drop(columns=["Country","City","State","Product Name","Sub-Category"])
datafinal.head()
# Out:
#         Ship Mode    Segment Region         Category     Sales  Quantity  \
# 0    Second Class   Consumer  South        Furniture  261.9600         2
# 1    Second Class   Consumer  South        Furniture  731.9400         3
# 2    Second Class  Corporate   West  Office Supplies   14.6200         2
# 3  Standard Class   Consumer  South        Furniture  957.5775         5
# 4  Standard Class   Consumer  South  Office Supplies   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164

# %%
datafinal.shape
# Out:
# (9994, 8)

# %%
datafinal["Ship Mode"].value_counts()
# Out:
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Ship Mode, dtype: int64

# %%
datafinal["Segment"].value_counts()
# Out:
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64

# %%
datafinal["Category"].value_counts()
# Out:
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: Category, dtype: int64

# %%
datafinal["Region"].value_counts()
# Out:
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: Region, dtype: int64

# %% [markdown]
# # Converting categorical values to numerical values

# %%
datafinal.replace({"Ship Mode":{"Standard Class":0,"Second Class":1,"First Class":2,"Same Day":3},"Segment":{"Consumer":0,"Corporate":1,"Home Office":2},
                 "Category":{"Office Supplies":0,"Furniture":1,"Technology":2},"Region":{"West":0,"East":1,"Central":2,"South":3}},inplace=True)
datafinal.head()
# Out:
#    Ship Mode  Segment  Region  Category     Sales  Quantity  Discount  \
# 0          1        0       3         1  261.9600         2      0.00
# 1          1        0       3         1  731.9400         3      0.00
# 2          1        1       0         0   14.6200         2      0.00
# 3          0        0       3         1  957.5775         5      0.45
# 4          0        0       3         0   22.3680         2      0.20
#
#      Profit
# 0   41.9136
# 1  219.5820
# 2    6.8714
# 3 -383.0310
# 4    2.5164

# %% [markdown]
# # Separating Database into x and y

# %%
x_db= datafinal.iloc[:,:-1]
print(x_db)
# Out:
#       Ship Mode  Segment  Region  Category     Sales  Quantity  Discount
# 0             1        0       3         1  261.9600         2      0.00
# 1             1        0       3         1  731.9400         3      0.00
# 2             1        1       0         0   14.6200         2      0.00
# 3             0        0       3         1  957.5775         5      0.45
# 4             0        0       3         0   22.3680         2      0.20
# ...         ...      ...     ...       ...       ...       ...       ...
# 9989          1        0       3         1   25.2480         3      0.20
# 9990          0        0       0         1   91.9600         2      0.00
# 9991          0        0       0         2  258.5760         2      0.20
# 9992          0        0       0         0   29.6000         4      0.00
# 9993          1        0       0         0  243.1600         2      0.00
#
# [9994 rows x 7 columns]

# %%
y_db= datafinal.iloc[:,-1]
print(y_db)
# Out:
# 0        41.9136
# 1       219.5820
# 2         6.8714
# 3      -383.0310
# 4         2.5164
#           ...
# 9989      4.1028
# 9990     15.6332
# 9991     19.3932
# 9992     13.3200
# 9993     72.9480
# Name: Profit, Length: 9994, dtype: float64

# %% [markdown]
# # Feature Rescaling

# %%
from sklearn.preprocessing import MinMaxScaler
scaler= MinMaxScaler()

# %%
x= x_db.copy()
num_vars=["Sales","Quantity"]
x[num_vars]=scaler.fit_transform(x[num_vars])
print(x)
# Out:
#       Ship Mode  Segment  Region  Category     Sales  Quantity  Discount
# 0             1        0       3         1  0.011552  0.076923      0.00
# 1             1        0       3         1  0.032313  0.153846      0.00
# 2             1        1       0         0  0.000626  0.076923      0.00
# 3             0        0       3         1  0.042280  0.307692      0.45
# 4             0        0       3         0  0.000968  0.076923      0.20
# ...         ...      ...     ...       ...       ...       ...       ...
# 9989          1        0       3         1  0.001096  0.153846      0.20
# 9990          0        0       0         1  0.004043  0.076923      0.00
# 9991          0        0       0         2  0.011403  0.076923      0.20
# 9992          0        0       0         0  0.001288  0.230769      0.00
# 9993          1        0       0         0  0.010722  0.076923      0.00
#
# [9994 rows x 7 columns]

# %% [markdown]
# # Spliting dataset into training set and testing set

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_db,y_db,test_size=0.25,random_state=100)
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (7495, 7) (2499, 7) (7495,) (2499,)

# %% [markdown]
# # Creating Machine Learning Model

# %%
from sklearn.ensemble import RandomForestRegressor
model=RandomForestRegressor(random_state=0,n_estimators=117)
model.fit(x_train,y_train)
# Out:
# RandomForestRegressor(n_estimators=117, random_state=0)

# %% [markdown]
# # Test Data Prediction

# %%
y_pred= model.predict(x_test)
from sklearn.metrics import r2_score
print("R2 Score=",r2_score(y_pred,y_test)*100)
# Out:
# R2 Score= 74.28753635077092

# %%
fig = plt.figure()
plt.scatter(y_test,y_pred)
fig.suptitle('y_test vs y_pred', fontsize=20)              # Plot heading
plt.xlabel('y_test', fontsize=18)                          # X-label
plt.ylabel('Y_pred', fontsize=16)
# Out:
# Text(0, 0.5, 'Y_pred')
